# %% [markdown]
# # Виды распределений

# %% [markdown]
# Загрузить таблицу и построить график распределений. Найти нормальное распределение.

# %%
import numpy as np
from scipy.stats import t
from scipy.stats import norm
import matplotlib.pyplot as plt
from scipy import stats
import pandas as pd
import io
import requests
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# Таблица цен на дома в Бостоне

# %% [markdown]
# Основные значения:
#
# * CRIM: This is the per capita crime rate by town
# * ZN: This is the proportion of residential land zoned for lots larger than 25,000 sq.ft.
# * INDUS: This is the proportion of non-retail business acres per town.
# * CHAS: This is the Charles River dummy variable (this is equal to 1 if tract bounds river; 0 otherwise)
# * NOX: This is the nitric oxides concentration (parts per 10 million)
# * RM: This is the average number of rooms per dwelling
# * AGE: This is the proportion of owner-occupied units built prior to 1940
# * DIS: This is the weighted distances to five Boston employment centers
# * RAD: This is the index of accessibility to radial highways
# * TAX: This is the full-value property-tax rate per 10,000 dollars
# * PTRATIO: This is the pupil-teacher ratio by town
# * B: This is calculated as 1000(Bk — 0.63)², where Bk is the proportion of people of African American descent by town
# * LSTAT: This is the percentage lower status of the population
# * MEDV: This is the median value of owner-occupied homes in 1000 dollars

# %%
url='http://yustiks.ru/housing.csv'
s=requests.get(url).content
names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
data=pd.read_csv(io.StringIO(s.decode('utf-8')),  delim_whitespace=True, names=names)
data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %% [markdown]
# Нарисовать частотные графики для всех значений. Можете ли вы найти следующие распределения в данных графиках?
#
#
# 1.   Нормальное
# 2.   Равномерное
# 3.   Биноминальное
# 4.   Бернулли
# 5.   Геометрическое
# 6.   Логнормальное

# %%
import math

# %%
plt.hist(data['CRIM'], int(round(math.log2(len(data['CRIM'])))), facecolor='g')
plt.xlabel('frequency')
plt.ylabel('CRIM')
plt.title('Частотный график CRIM')
plt.grid(True)
plt.show()

# %% [markdown]
# # Геометрическое

# %%
plt.hist(data['ZN'], int(round(math.log2(len(data['ZN'])))), facecolor='g')
plt.xlabel('frequency')
plt.ylabel('ZN')
plt.title('Частотный график ZN')
plt.grid(True)
plt.show()

# %% [markdown]
# # Геометрическое или близкое к нему

# %%
plt.hist(data['INDUS'], int(round(math.log2(len(data['INDUS'])))), facecolor='g')
plt.xlabel('frequency')
plt.ylabel('INDUS')
plt.title('Частотный график INDUS')
plt.grid(True)
plt.show()

# %% [markdown]
# # Неопределенное

# %%
plt.hist(data['CHAS'], int(round(math.log2(len(data['CHAS'])))), facecolor='g')
plt.xlabel('frequency')
plt.ylabel('CHAS')
plt.title('Частотный график CHAS')
plt.grid(True)
plt.show()

# %% [markdown]
# # Бернулли

# %%
plt.hist(data['NOX'], int(round(math.log2(len(data['NOX'])))), facecolor='g')
plt.xlabel('frequency')
plt.ylabel('NOX')
plt.title('Частотный график NOX')
plt.grid(True)
plt.show()

# %% [markdown]
# # Неопределенное

# %%
plt.hist(data['RM'], int(round(math.log2(len(data['RM'])))), facecolor='g')
plt.xlabel('frequency')
plt.ylabel('RM')
plt.title('Частотный график RM')
plt.grid(True)
plt.show()

# %% [markdown]
# # Возможно при большей выборке устремиться к нормальному

# %%
plt.hist(data['AGE'], int(round(math.log2(len(data['AGE'])))), facecolor='g')
plt.xlabel('frequency')
plt.ylabel('AGE')
plt.title('Частотный график AGE')
plt.grid(True)
plt.show()

# %% [markdown]
# # Неопределенное

# %%
plt.hist(data['DIS'], int(round(math.log2(len(data['DIS'])))), facecolor='g')
plt.xlabel('frequency')
plt.ylabel('DIS')
plt.title('Частотный график DIS')
plt.grid(True)
plt.show()

# %% [markdown]
# # Геометрическое

# %%
plt.hist(data['RAD'], int(round(math.log2(len(data['RAD'])))), facecolor='g')
plt.xlabel('frequency')
plt.ylabel('RAD')
plt.title('Частотный график RAD')
plt.grid(True)
plt.show()

# %% [markdown]
# # Неопределенное

# %%
plt.hist(data['TAX'], int(round(math.log2(len(data['TAX'])))), facecolor='g')
plt.xlabel('frequency')
plt.ylabel('TAX')
plt.title('Частотный график TAX')
plt.grid(True)
plt.show()

# %% [markdown]
# # Неопределенное

# %%
plt.hist(data['PTRATIO'], int(round(math.log2(len(data['PTRATIO'])))), facecolor='g')
plt.xlabel('frequency')
plt.ylabel('PTRATIO')
plt.title('Частотный график PTRATIO')
plt.grid(True)
plt.show()

# %% [markdown]
# # Неопределенное

# %%
plt.hist(data['B'], int(round(math.log2(len(data['B'])))), facecolor='g')
plt.xlabel('frequency')
plt.ylabel('B')
plt.title('Частотный график B')
plt.grid(True)
plt.show()

# %% [markdown]
# # Неопределенное

# %%
plt.hist(data['LSTAT'], int(round(math.log2(len(data['LSTAT'])))), facecolor='g')
plt.xlabel('frequency')
plt.ylabel('LSTAT')
plt.title('Частотный график LSTAT')
plt.grid(True)
plt.show()

# %% [markdown]
# # Логнормальное

# %%
plt.hist(data['MEDV'], int(round(math.log2(len(data['MEDV'])))), facecolor='g')
plt.xlabel('frequency')
plt.ylabel('MEDV')
plt.title('Частотный график MEDV')
plt.grid(True)
plt.show()

# %% [markdown]
# # Неопределенное

# %% [markdown]
# Напишите код, который будет рисовать распределения попарно - точечные распределение

# %%
sns.set(style="ticks", color_codes=True)
g = sns.pairplot(data)

# %% [markdown]
# Загрузить таблицу Happiness report. Нарисовать матрицу ковариаций попарно.

# %%
url="http://yustiks.ru/dataset/world-happiness-report-2019.csv"
data=pd.read_csv(url)
data.head()
# Out:
#   Country (region)  Ladder  SD of Ladder  Positive affect  Negative affect  \
# 0          Finland       1             4             41.0             10.0
# 1          Denmark       2            13             24.0             26.0
# 2           Norway       3             8             16.0             29.0
# 3          Iceland       4             9              3.0              3.0
# 4      Netherlands       5             1             12.0             25.0
#
#    Social support  Freedom  Corruption  Generosity  Log of GDP\nper capita  \
# 0             2.0      5.0         4.0        47.0                    22.0
# 1             4.0      6.0         3.0        22.0                    14.0
# 2             3.0      3.0         8.0        11.0                     7.0
# 3             1.0      7.0        45.0         3.0                    15.0
# 4            15.0     19.0        12.0         7.0                    12.0
#
#    Healthy life\nexpectancy
# 0                      27.0
# ...

# %% [markdown]
# Сколько в данной таблице отсутствующих значений? Написать ответ. Если есть отсутствующие значения в выборке country, убрать (drop). Написать код.

# %%
print (data.count())
# Out:
# Country (region)            156
# Ladder                      156
# SD of Ladder                156
# Positive affect             155
# Negative affect             155
# Social support              155
# Freedom                     155
# Corruption                  148
# Generosity                  155
# Log of GDP\nper capita      152
# Healthy life\nexpectancy    150
# dtype: int64

# %%
data_clear = data.dropna()
print (data_clear.count())
# Out:
# Country (region)            140
# Ladder                      140
# SD of Ladder                140
# Positive affect             140
# Negative affect             140
# Social support              140
# Freedom                     140
# Corruption                  140
# Generosity                  140
# Log of GDP\nper capita      140
# Healthy life\nexpectancy    140
# dtype: int64

# %% [markdown]
# Сколько стран в выборке? Написать ответ. Можно ли сказать, что данные значения - это **проблема классификации**?

# %%
data_clear
# Out:
#              Country (region)  Ladder  SD of Ladder  Positive affect  \
# 0                     Finland       1             4             41.0
# 1                     Denmark       2            13             24.0
# 2                      Norway       3             8             16.0
# 3                     Iceland       4             9              3.0
# 4                 Netherlands       5             1             12.0
# 5                 Switzerland       6            11             44.0
# 6                      Sweden       7            18             34.0
# 7                 New Zealand       8            15             22.0
# 8                      Canada       9            23             18.0
# 9                     Austria      10            10             64.0
# 10                  Australia      11            26             47.0
# 11                 Costa Rica      12            62              4.0
# 12                     Israel      13            14            104.0
# ...

# %%
len(data["Country (region)"].unique())
# Out:
# 156

# %% [markdown]
# **В датафрейме уникальных значений стран 156.
# Мы будем работать с выборкой, полученной после удаления всех строк с Nan значениями, равной 140 странам.
# Конечно, здесь есть проблема классификации (если я правильно понимаю данный термин), дело в том, что
# многие страны имеют совершенно разные уровни социального развития. Например страны африканского континента имеют уровень жизни (и соответственно уровень социальных благ,
# значительно ниже, чем например европейские страны. Способ измерения "положительных эмоций" или уровня "свободы" нам неизвестен, шкалы тоже нет. А мы имеем дело с ранжиром.
# Предположим Ирак на 126 месте, а Сингапур на 33. Это вовсе не означает, что в Ираке степень удовлетворенности в три раза ниже.
# Если мы добавим(убавим) другие страны в таблицу разрыв между Ираком и Сингапуром изменится. Чтобы статистически анализировать данную выборку
# надо хотя бы знать начальные данные на основе которых сделан ранжир**

# %% [markdown]
# Нарисовать sns.pairplot для класс - страна. Из графика сделать вывод о том, какие страны похожи.

# %%
country_by_continent = pd.read_json('country-by-continent.json')
country_by_continent
# Out:
#          continent                               country
# 0             Asia                           Afghanistan
# 1           Europe                               Albania
# 2           Africa                               Algeria
# 3          Oceania                        American Samoa
# 4           Europe                               Andorra
# 5           Africa                                Angola
# 6    North America                              Anguilla
# 7       Antarctica                            Antarctica
# 8    North America                   Antigua and Barbuda
# 9    South America                             Argentina
# 10            Asia                               Armenia
# 11   North America                                 Aruba
# 12         Oceania                             Australia
# 13          Europe                               Austria
# 14            Asia                            Azerbaijan
# ...

# %%
data_continent = pd.merge(left = data_clear, right=country_by_continent, left_on='Country (region)', right_on='country')
data_continent.head(10)
# Out:
#   Country (region)  Ladder  SD of Ladder  Positive affect  Negative affect  \
# 0          Finland       1             4             41.0             10.0
# 1          Denmark       2            13             24.0             26.0
# 2           Norway       3             8             16.0             29.0
# 3          Iceland       4             9              3.0              3.0
# 4      Netherlands       5             1             12.0             25.0
# 5      Switzerland       6            11             44.0             21.0
# 6           Sweden       7            18             34.0              8.0
# 7      New Zealand       8            15             22.0             12.0
# 8           Canada       9            23             18.0             49.0
# 9          Austria      10            10             64.0             24.0
#
#    Social support  Freedom  Corruption  Generosity  Log of GDP\nper capita  \
# ...

# %%
del data_continent['country']
data_continent.head(10)
# Out:
#   Country (region)  Ladder  SD of Ladder  Positive affect  Negative affect  \
# 0          Finland       1             4             41.0             10.0
# 1          Denmark       2            13             24.0             26.0
# 2           Norway       3             8             16.0             29.0
# 3          Iceland       4             9              3.0              3.0
# 4      Netherlands       5             1             12.0             25.0
# 5      Switzerland       6            11             44.0             21.0
# 6           Sweden       7            18             34.0              8.0
# 7      New Zealand       8            15             22.0             12.0
# 8           Canada       9            23             18.0             49.0
# 9          Austria      10            10             64.0             24.0
#
#    Social support  Freedom  Corruption  Generosity  Log of GDP\nper capita  \
# ...

# %%
# Если код ниже не работает, измените код, используя материал лекций. Пишите на почту, если испытываете проблемы: yustiks@gmail.com
sns.set(style="ticks", color_codes=True)
fig = sns.pairplot(data = data_continent, hue='continent')
plt.show()

# %% [markdown]
# **По странам наводить статистику не было смысла, разбил по континентам.
# И хотя при ранжированных данных такое сравнение бессмысленно скорее всего, для практики проделал необходимые действия.
# Данных много. Понять, что-либо сложно, но вроде бы можно предположить, что явно схожих континетнов нет**

# %% [markdown]
# Посчитать матрицу корреляций для таблицы. Написать код. Сделать график. Какие можно сделать выводы?

# %%
data_clear.corr()
# Out:
#                             Ladder  SD of Ladder  Positive affect  \
# Ladder                    1.000000      0.555987         0.511870
# SD of Ladder              0.555987      1.000000         0.090332
# Positive affect           0.511870      0.090332         1.000000
# Negative affect           0.539677      0.632734         0.351906
# Social support            0.833412      0.600087         0.433333
# Freedom                   0.546414      0.250246         0.696567
# Corruption                0.224394      0.253344         0.225905
# Generosity                0.485704      0.386337         0.417061
# Log of GDP\nper capita    0.820608      0.663977         0.310843
# Healthy life\nexpectancy  0.826677      0.637554         0.339032
#
#                           Negative affect  Social support   Freedom  \
# Ladder                           0.539677        0.833412  0.546414
# SD of Ladder                     0.632734        0.600087  0.250246
# ...

# %% [markdown]
# **Боюсь ошибиться, но по-моему, единственный уверенный вывод мы можем сделать следующий
# Продолжительность жизни, ВВП страны и социальная поддержка имеют наибольшие веса в методике используемой для определения удовлетворенностью жизнью в стране.**

# %% [markdown]
# **Регрессионный анализ** - можно ли провести линейную зависимость между двумя выборками. Возьмем Ladder - удовлетворение жизнью, и generosity - доброта. Мы хотим найти прямую, которая разделит точки в пространстве наполовину. Это можно сделать графически. Нарисовать график. Можно ли сказать, что данная прямая является собственным вектором? При проецировании данных на эту прямую разброс данных максимален?

# %%
sns.jointplot(x='Ladder', y='Generosity', data=data_clear, kind='reg')

# %% [markdown]
# **Честно признаться, не понял вопроса.
# Можно провести бесконечное количество прямых разделяющих данное пространство пополам.
# И это точно не является определением прямой на которой лежит собственный вектор, т.к. собственный вектор лежит
# на прямой вычисляемой по методу наименьших квадратов, а она не делит пространство пополам.
# Насколько я понимаю на графике именно такая прямая, и да собственный вектор коллинеарен ей.
# Одна из прямых которая должна точно делить пространство точек пополам - это медианная прямая, горизонтальная или вертикальная прямая,
# проходящая через точку на оси x или y, являющаяся медианным значением соответствующей выборки.
# Кстати, буду весьма признателен если подскажете как на данный график нанести еще какую-нибудь прямую или кривую.**

# %% [markdown]
# # Дискретное распределение случайной величины

# %% [markdown]
# Напишите код для моделирования 10 подбрасываний игрального кубика. Начертите диаграму histogram. Какое это распределение?

# %% [markdown]
# **Сначала отработаем функцию рассчитывающую подбрасывание кубика**

# %%
import random

# %%
def generation(n: int):
    count = 0
    dict = {x: 0 for x in range(1,7)}
    while count < n:  
        dict[random.randint(1,6)] += 1
        count += 1
    return dict

# %%
toss = generation(10)
toss
data = pd.DataFrame([toss])
data
# Out:
#    1  2  3  4  5  6
# 0  5  2  0  1  1  1

# %%
data.plot.bar(y = [1,2,3,4,5,6])

# %%
toss = generation(1000)
toss
data = pd.DataFrame([toss])
data.plot.bar(y = [1,2,3,4,5,6])

# %%
toss = generation(1000000)
toss
data = pd.DataFrame([toss])
data.plot.bar(y = [1,2,3,4,5,6])

# %% [markdown]
# **Создадим функцию для биномиального распределения.
# Будем проводить N экспериментов с n подбрасываниями**

# %%
toss=generation(10)
toss1=generation(10)
toss[1] = toss[1] + toss1[1]
toss[1]
# Out:
# 3

# %%
def binom (n: int, N: int):
    response = {x: [] for x in range(1,7)}
    count = 0
    while count < N:
        toss = generation(n)
        for key in response:
            response[key].append(toss[key])
        count += 1
    return response

# %%
toss = binom(10,10)
data = pd.DataFrame([toss])

# %%
import math

# %%
plt.hist(data[1], 10, facecolor='g')
plt.xlabel('frequency')
plt.ylabel('1')
plt.title('Частотный график количества выпадывания единички в 10 экспериментах по 10 бросков')
plt.grid(True)
plt.show()

# %% [markdown]
# **Такой график можно построить для любой грани кубика, например для 6**

# %%
plt.hist(data[6], 10, facecolor='g')
plt.xlabel('frequency')
plt.ylabel('6')
plt.title('Частотный график количества выпадывания шестерки в 10 экспериментах по 10 бросков')
plt.grid(True)
plt.show()

# %% [markdown]
# **Очевидно, что данных недостаточно для понимания какому распределению подченена генеральная совокупность.
# Мы знаем, что это должно быть биномиальное распределение и, что оно должно стремиться при большом количестве испытаний N
# и большом количестве бросков в одном испытании n к нормальному распределению, проверим увеличив оба параметра**

# %% [markdown]
# Напишите код для моделирования 1000 подбрасываний игрального кубика. Начертите диаграму histogram. Почему график изменился? Как применить центральную предельную теорему?

# %%
toss = binom(100,1000)
data = pd.DataFrame([toss])

# %%
plt.hist(data[1], 100, facecolor='g')
plt.xlabel('frequency')
plt.ylabel('1')
plt.title('Частотный график количества выпадывания единички в 1000 экспериментах по 100 бросков')
plt.grid(True)
plt.show()

# %% [markdown]
# **Можно еще увеличить количество испытаний**

# %%
toss = binom(100,100000)
data = pd.DataFrame([toss])

# %%
plt.hist(data[1], 100, facecolor='g')
plt.xlabel('frequency')
plt.ylabel('1')
plt.title('Частотный график количества выпадывания единички в 100000 экспериментах по 100 бросков')
plt.grid(True)
plt.show()

# %%
import seaborn
from matplotlib.pyplot import show

# %%
seaborn.distplot(toss[1], fit=norm)  # подготовим гистограмму и кривую распределения
show()

# %% [markdown]
# **Мораль - получили биномиальное распределение, приближающееся к нормальному**
